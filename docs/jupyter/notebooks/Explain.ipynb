# %%
# %load_ext taegis_magic

# %%
# %taegis auth login --use-universal-authentication

# %%
tenant={insert tenant here}
region={insert region here}

# %%
# %%taegis events search --assign processes --tenant "$tenant" --region "$region"
# FROM process
# EARLIEST=-1d | HEAD 3

# %%
from taegis_magic.pandas.explain import get_command_line_explanation

# %%
valid_ret = get_command_line_explanation(processes, region=region, tenant_id=tenant)
# Overriding event_id_column to get a DataFrame to return without explanations.
invalid_ret = get_command_line_explanation(processes, region=region, tenant_id=tenant, event_id_column="process_correlation_id")

# %%
print(valid_ret)

# %%
print(invalid_ret)
