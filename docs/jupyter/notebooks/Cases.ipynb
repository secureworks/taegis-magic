# %%
# %load_ext taegis_magic

# %%
# %%taegis alerts search --track --assign alerts_dataframe
# FROM alert
# EARLIEST=-1d | head 5

# %%
# %taegis cases evidence stage alerts alerts_dataframe

# %%
# %taegis cases evidence show

# %%
# %%taegis events search --track --assign events_dataframe --tenant 96100
# FROM process
# EARLIEST=-1d | head 5

# %%
# %taegis cases evidence stage events events_dataframe

# %%
# %taegis cases evidence show

# %%
# %taegis cases search-queries list

# %%
# %taegis cases search-queries stage

# %%
# %%writefile key_findings.md
# My key findings!

# %%
# %taegis cases create --title "Test" --key-findings key_findings.md --type-id "threat_hunt" --primary-status-id "draft" --assignee-id "@me"
