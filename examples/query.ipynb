# %%
# %reload_ext taegis_magic

# %%
# %taegis -h
# Out:
# usage: taegis_magic_parser [-h] [--assign NAME | --append NAME]
#                            [--display NAME]
#                            [--disable-return-display {off,all,on_empty}]
#                            [--cell CELL] [-t] [-f CELL_TEMPLATE_FILE]
#                            [--cache]
#
# options:
#   -h, --help            show this help message and exit
#   --assign NAME         Assign results as pandas DataFrame to NAME
#   --append NAME         Append results as pandas DataFrame to NAME
#   --display NAME        Display NAME as markdown table
#   --disable-return-display {off,all,on_empty}
#                         Disable automatic display of return metadata table,
#                         does not work with --cache
#   --cell CELL           Cell contents
#   -t, --cell-template   Use a Jinja2 Template for input, uses Shell Namespace
#                         as variables
#   -f, --cell-template-file CELL_TEMPLATE_FILE
#                         Use a template file instead of providing cell input
#   --cache               Save output to cache / Load output from cache (if
#                         present)
#
#  Usage: taegis [OPTIONS] COMMAND [ARGS]...
#  Taegis Magic help menu.
# ╭─ Options ───────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ --warning                 --no-warning          Set taegis_magic logger level for this command.                 │
# │                                                 [default: no-warning]                                           │
# │ --verbose                 --no-verbose          Set taegis_magic logger level for this command.                 │
# │                                                 [default: no-verbose]                                           │
# │ --debug                   --no-debug            Set taegis_magic logger level for this command.                 │
# │                                                 [default: no-debug]                                             │
# │ --trace                   --no-trace            Set taegis_magic logger level for this command.                 │
# │                                                 [default: no-trace]                                             │
# │ --error                   --no-error            Set taegis_magic logger level for this command.                 │
# │                                                 [default: no-error]                                             │
# │ --sdk-warning             --no-sdk-warning      Set taegis_sdk_python logger level for this command.            │
# │                                                 [default: no-sdk-warning]                                       │
# │ --sdk-verbose             --no-sdk-verbose      Set taegis_sdk_python logger level for this command.            │
# │                                                 [default: no-sdk-verbose]                                       │
# │ --sdk-debug               --no-sdk-debug        Set taegis_sdk_python logger level for this command.            │
# │                                                 [default: no-sdk-debug]                                         │
# │ --sdk-error               --no-sdk-error        Set taegis_sdk_python logger level for this command.            │
# │                                                 [default: no-sdk-error]                                         │
# │ --install-completion                            Install completion for the current shell.                       │
# │ --show-completion                               Show completion for the current shell, to copy it or customize  │
# │                                                 the installation.                                               │
# │ --help                -h                        Show this message and exit.                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─ Commands ──────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ version          Taegis Magic version information.                                                              │
# │ alerts           Taegis Alerts Commands.                                                                        │
# │ auth             Taegis Authentication Commands.                                                                │
# │ audits           Taegis Audit Commands.                                                                         │
# │ clients          Taegis Clients Commands.                                                                       │
# │ configure        Taegis Magic Configuration Commands.                                                           │
# │ events           Taegis Events Commands.                                                                        │
# │ investigations   Taegis Investigation Commands.                                                                 │
# │ notebook         Taegis Notebook Commands.                                                                      │
# │ preferences      Taegis Preferences Commands.                                                                   │
# │ rules            Taegis Rules Commands.                                                                         │
# │ search           Taegis Search Commands.                                                                        │
# │ sharelinks       Taegis Sharelinks Commands.                                                                    │
# │ subjects         Taegis Subjects Commands.                                                                      │
# │ tenant-profiles  Taegis Tenant Profile Commands.                                                                │
# │ tenants          Taegis Tenant Commands.                                                                        │
# │ threat           Taegis Threat Intelligence Commands.                                                           │
# │ users            Taegis User Commands.                                                                          │
# │ process-trees    Taegis Process Trees Commands.                                                                 │
# │ query            Taegis Query Commands.                                                                         │
# │ orchestration    Taegis Orchestration Commands.                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from taegis_sdk_python.config import write_to_config
write_to_config("magics.regions", "pilot", "https://api.pilot.8labs.io")

# %%
# %taegis query search --cell "SELECT * FROM process LIMIT 5000" --time-range-start "2026-06-10T00:00:00Z" --time-range-end "2026-06-11T00:00:00Z" --tenant 93387 --workload "search-qee-runner" --region  pilot --assign process
# Out:
# Executing query: 0 poll [00:00, ?poll/s]
# Fetching results:   0%|          | 0/5 [00:00<?, ?rows/s]
# **Taegis Results**
#
# |Region          |Tenant             |Service          |Total Results                       |
# |----------------|-------------------|-----------------|------------------------------------|
# |pilot|93387|query_relay|5000|

# %%
# %%taegis query search --tenant 93387 --workload "search-qee-runner" --region  pilot --assign process
# SELECT
#     *
# FROM process
# LIMIT 5000
# Out:
# Executing query: 0 poll [00:00, ?poll/s]
# Fetching results:   0%|          | 0/5 [00:00<?, ?rows/s]
# **Taegis Results**
#
# |Region          |Tenant             |Service          |Total Results                       |
# |----------------|-------------------|-----------------|------------------------------------|
# |pilot|93387|query_relay|5000|
